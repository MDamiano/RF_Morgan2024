# %%
! pip install numpy pandas scikit-learn xlrd
import sys
! git clone https://github.com/MDamiano/RF_Morgan2024.git
sys.path.append('./repository')
# Out:
# ...
# fatal: destination path 'RF_Morgan2024' already exists and is not an empty directory.

# %%
from RF_Morgan2024.morgan2024 import *

# %%
rf_VIS = RF_Morgan2024('VIS')
rf_NIR = RF_Morgan2024('NIR')
rf_NUV = RF_Morgan2024('NUV')

# %%
diameter = 8
log_contrast = -10.0
throughput = 0.5
iwa = 25

# %%
print("The yield in the VIS band is " + str(int(rf_VIS.sim(diameter,log_contrast,throughput,iwa))))
print("The yield in the NIR band is " + str(int(rf_NIR.sim(diameter,log_contrast,throughput,iwa))))
print("The yield in the NUV band is " + str(int(rf_NUV.sim(diameter,log_contrast,throughput,iwa))))
# Out:
# The yield in the VIS band is 34
# The yield in the NIR band is 18
# The yield in the NUV band is 27
